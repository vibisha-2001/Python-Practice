# %%
my_str="hi my name is vibisha"

# %%
my_str.split()
# Out:
# ['hi', 'my', 'name', 'is', 'vibisha']

# %%
word='' # store the word
output=[] # store the final output

for i in my_str:
    # check for the space
    if i!='':
        # formulate the word
        word +=i
        print(word)
    else:
        output=output+[word]
        word=''
        print(output)
output=output+[word]
print(output)
# Out:
# h
# hi
# hi
# hi m
# hi my
# hi my
# hi my n
# hi my na
# hi my nam
# hi my name
# hi my name
# hi my name i
# hi my name is
# hi my name is
# hi my name is v
# hi my name is vi
# hi my name is vib
# hi my name is vibi
# hi my name is vibis
# hi my name is vibish
# hi my name is vibisha
# ['hi my name is vibisha']

# %%
word='' # store the word
output=[] # store the final output

for i in my_str:
    # check for the space
    if i!='':
        # formulate the word
        word =i+word
        print(word)
    else:
        output=output+[word]
        word=''
        # print(output)
output=output+[word]
print(output)
# Out:
# h
# ih
#  ih
# m ih
# ym ih
#  ym ih
# n ym ih
# an ym ih
# man ym ih
# eman ym ih
#  eman ym ih
# i eman ym ih
# si eman ym ih
#  si eman ym ih
# v si eman ym ih
# iv si eman ym ih
# biv si eman ym ih
# ibiv si eman ym ih
# sibiv si eman ym ih
# hsibiv si eman ym ih
# ahsibiv si eman ym ih
# ['ahsibiv si eman ym ih']

# %%
word='' # store the word
output=[] # store the final output

for i in my_str:
    # check for the space
    if i!=' ':
        # formulate the word
        word =i+word
        print(word)
    else:
        output=output+[word]
        word=' '
        print(output)
output=[word]+output
print(output)
# Out:
# h
# ih
# ['ih']
# m
# ym
# ['ih', 'ym ']
# n
# an
# man
# eman
# ['ih', 'ym ', 'eman ']
# i
# si
# ['ih', 'ym ', 'eman ', 'si ']
# v
# iv
# biv
# ibiv
# sibiv
# hsibiv
# ahsibiv
# ['ahsibiv ', 'ih', 'ym ', 'eman ', 'si ']

# %%
def mimic_split(s,delimiter):
    word='' # store the word
    output=[] # store the final output

    for i in my_str:
        # check for the space
        if i!=delimiter:
            # formulate the word
            word +=i
        
        else:
            output=output+[word]
            word=' '
    
    output=output+[word]
    return output

# %%
mimic_split(my_str," ")
# Out:
# ['hi', ' my', ' name', ' is', ' vibisha']
